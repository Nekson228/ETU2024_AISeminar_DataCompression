# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cov = np.array([
    [5, 0], 
    [0, 0.001]
])
mean = np.array([0, 0])
data = np.random.multivariate_normal(mean, cov, size=1000)
data
# Out:
# array([[-1.73031325e-01, -5.66398678e-02],
#        [-7.85804211e-01, -1.71145496e-03],
#        [ 1.07821781e+00, -1.41597953e-02],
#        ...,
#        [-3.49150535e+00, -5.06433797e-02],
#        [-1.34407925e+00, -1.39638493e-02],
#        [-1.36678177e+00,  3.79721301e-02]])

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Helvetica"
})

# %%
plt.scatter(data[:, 0], data[:, 1])
plt.ylim(-5, 5)

plt.axhline(0, color='black', lw=1)
plt.axvline(0, color='black', lw=1)
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Original Data')
plt.show()

# %%
B = np.array([1, 0]).reshape(-1, 1)
B
# Out:
# array([[1],
#        [0]])

# %%
transformed = B.T @ data.T
decoded = (B @ transformed).T
decoded
# Out:
# array([[-0.17303133,  0.        ],
#        [-0.78580421,  0.        ],
#        [ 1.07821781,  0.        ],
#        ...,
#        [-3.49150535,  0.        ],
#        [-1.34407925,  0.        ],
#        [-1.36678177,  0.        ]])

# %%
plt.scatter(decoded[:, 0], decoded[:, 1], color='orange')
plt.ylim(-5, 5)

plt.axhline(0, color='black', lw=1)
plt.axvline(0, color='black', lw=1)
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Compressed Data')
plt.show()
