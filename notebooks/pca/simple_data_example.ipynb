# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cov = np.array([
    [5, 0], 
    [0, 0.001]
])
mean = np.array([0, 0])
data = np.random.multivariate_normal(mean, cov, size=1000)
data
# Out:
# array([[-0.31158759, -0.0064595 ],
#        [-1.28360364,  0.04463341],
#        [-0.76085116, -0.00990732],
#        ...,
#        [ 1.77621717, -0.00613585],
#        [ 3.04641842, -0.04740756],
#        [ 2.71767003, -0.01703978]])

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Helvetica"
})

# %%
plt.scatter(data[:, 0], data[:, 1])
plt.ylim(-5, 5)

plt.axhline(0, color='black', lw=1)
plt.axvline(0, color='black', lw=1)
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Original Data')
plt.show()

# %%
B = np.array([1, 0]).reshape(-1, 1)
B
# Out:
# array([[1],
#        [0]])

# %%
transformed = B.T @ data.T
decoded = (B @ transformed).T
decoded
# Out:
# array([[-0.31158759,  0.        ],
#        [-1.28360364,  0.        ],
#        [-0.76085116,  0.        ],
#        ...,
#        [ 1.77621717,  0.        ],
#        [ 3.04641842,  0.        ],
#        [ 2.71767003,  0.        ]])

# %%
plt.scatter(decoded[:, 0], decoded[:, 1], color='orange')
plt.ylim(-5, 5)

plt.axhline(0, color='black', lw=1)
plt.axvline(0, color='black', lw=1)
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Compressed Data')
plt.show()
